# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import scipy.stats as stats

# Split the data

# %%
fl = {
    'Age': -0.360231,
    'Selling_Price': -0.035121,
    'Present_Price': 0.078725,
    'Kms_Driven': 0.350131,
    'Owner': -30.152326,
    'Fuel_Type_Diesel': -7.293622,
    'Seller_Type_Individual': -2.570020,
    'Transmission_Manual': 14.351418,
    'Fuel_Type_Petrol': 6.887121
}
# fl.keys()
# fitted_lambda = pd.DataFrame(data=fl,index=fl.keys())
# fitted_lambda

# fitted_lambda = pd.Series(np.zeros(len(fl.keys()), dtype=np.float64), index=fl.keys())
fitted_lambda = pd.Series(data = fl.values(), index=fl.keys())
fitted_lambda
# Out:
# Age                       -0.360231
# Selling_Price             -0.035121
# Present_Price              0.078725
# Kms_Driven                 0.350131
# Owner                    -30.152326
# Fuel_Type_Diesel          -7.293622
# Seller_Type_Individual    -2.570020
# Transmission_Manual       14.351418
# Fuel_Type_Petrol           6.887121
# dtype: float64

# %%
data = {
    "Age": 5,
    # "Selling_Price": 3.35,
    "Present_Price": 5.59,
    "Kms_Driven": 27000,
    "Owner": 0,
    "Fuel_Type_Diesel": 1,
    "Fuel_Type_Petrol": 0,
    "Seller_Type_Individual": 1, # dealer 1 individual 0
    "Transmission_Manual": 1 # mannual 1 auto 1
}

# %%
# wagonr,2011,2.85,4.15,5200,Petrol,Dealer,Manual,0

# 5	3.35	5.59	27000	Petrol	Dealer	Manual	0

data2 = {"Age": 5,
    # "Selling_Price": 3.35,
    "Present_Price": 5.59,
    "Kms_Driven": 27000,
    "Owner": 0,
    "Fuel_Type_Diesel": 0,
    "Fuel_Type_Petrol": 0,
    "Seller_Type_Individual": 1, # dealer 1 individual 0
    "Transmission_Manual":1 }# mannual 1 auto 1}

# %%
# 6	4.75	9.54	43000	Diesel	Dealer	Manual	0\

data3 ={"Age": 6,
    # "Selling_Price": 9.54,
    "Present_Price": 4.75,
    "Kms_Driven": 43000,
    "Owner": 0,
    "Fuel_Type_Diesel": 1,
    "Fuel_Type_Petrol": 0,
    "Seller_Type_Individual": 0, # dealer 1 individual 0
    "Transmission_Manual":1 }

# %%
data4 =data_dict = {
    # "Car_Name": "ciaz",
    "Year": 2015,
    # "Selling_Price": 7.5,
    "Present_Price": 9.94,
    "Kms_Driven": 15000,
    "Fuel_Type": "Petrol",
    "Seller_Type": "Dealer",
    "Transmission": "Automatic",
    "Owner": 0
}

# %%
user_ip: dict = {'Car_Name':'ritz',
                  'Year':2014,
                  'Selling_Price':3.35,
                  'Present_Price':5.59,
                  'Kms_Driven':27000,
                  'Fuel_Type':'Petrol',
                  'Seller_Type':'Dealer',
                  'Transmission':'Manual',
                  'Owner':0}

# %%
df = pd.DataFrame(data4,index=[0])
df
# Out:
#    Year  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 0  2015           9.94       15000    Petrol      Dealer    Automatic      0

# %%
for col in df.columns:
    df[col] = stats.boxcox(df[col]+1, fitted_lambda[col])

# %%
df
# Out:
#         Age  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0  1.320186       2.032689   98.846722    0.0               0.0
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0               0.0                0.323577          1456.437013

# %%
df.drop('Fuel_Type_Petrol',axis=1,inplace=True)

# %%
df.head()
# Out:
#         Age  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0  1.320186       2.032689   98.846722    0.0               0.0
#
#    Seller_Type_Individual  Transmission_Manual
# 0                0.323577          1456.437013

# %%
import pickle
file_path = "E:\\python\\2.PROJECTS\\car sales prediction\\artifacts\
+08, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 6.88655263e-02,
#         3.09967794e+02, 1.39518332e+06, 6.27980239e+09, 9.54660807e+07,
#         0.00000000e+00, 0.00000000e+00, 3.12509932e+05, 1.40662563e+09,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.02300688e+03,
#         4.60461431e+06, 2.07256405e+10, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 3.34883144e+00, 1.50732878e+04,
#         6.78457570e+07, 3.05377753e+11, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.09624599e-02, 4.93426786e+01, 2.22094306e+05, 9.99659567e+08,
#         4.49952665e+12]])

# %%
feature_names = poly_features.get_feature_names_out()

# %%
df_poly = pd.DataFrame(X_poly, columns=feature_names)

# %%
df_poly
# Out:
#         Age  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0  1.320186       2.032689   98.846722    0.0               0.0
#
#    Seller_Type_Individual  Transmission_Manual     Age^2  Age Present_Price  \
# 0                0.323577          1456.437013  1.742892           2.683528
#
#    Age Kms_Driven  ...  Fuel_Type_Diesel^2 Transmission_Manual^2  \
# 0      130.496105  ...                                       0.0
#
#    Fuel_Type_Diesel Seller_Type_Individual^3  \
# 0                                        0.0
#
#    Fuel_Type_Diesel Seller_Type_Individual^2 Transmission_Manual  \
# 0                                                0.0
#
#    Fuel_Type_Diesel Seller_Type_Individual Transmission_Manual^2  \
# 0                                                0.0
#
#    Fuel_Type_Diesel Transmission_Manual^3  Seller_Type_Individual^4  \
# 0                                     0.0                  0.010962
#
#    Seller_Type_Individual^3 Transmission_Manual  \
# 0                                     49.342679
#
#    Seller_Type_Individual^2 Transmission_Manual^2  \
# 0                                   222094.305933
#
#    Seller_Type_Individual Transmission_Manual^3  Transmission_Manual^4
# 0                                  9.996596e+08           4.499527e+12
#
# [1 rows x 329 columns]

# %% [markdown]
# # remove the not required columns

# %%
specified_columns = ['Present_Price', 'Transmission_Manual', 'Seller_Type_Individual^2',
       'Age Seller_Type_Individual Transmission_Manual',
       'Kms_Driven Fuel_Type_Diesel Transmission_Manual', 'Age^4',
       'Age^2 Present_Price^2', 'Age^2 Owner Transmission_Manual',
       'Age^2 Fuel_Type_Diesel Seller_Type_Individual',
       'Age^2 Fuel_Type_Diesel Transmission_Manual',
       'Age Present_Price^2 Fuel_Type_Diesel',
       'Age Kms_Driven^2 Seller_Type_Individual', 'Present_Price^4',
       'Present_Price^2 Fuel_Type_Diesel Transmission_Manual',
       'Present_Price^2 Seller_Type_Individual Transmission_Manual',
       'Present_Price Kms_Driven^2 Owner',
       'Present_Price Kms_Driven Owner Transmission_Manual',
       'Present_Price Owner Seller_Type_Individual Transmission_Manual',
       'Kms_Driven^3 Fuel_Type_Diesel', 'Kms_Driven^3 Transmission_Manual']
df_poly = df_poly.reindex(columns=specified_columns, fill_value=0)

# %%
df_poly
# Out:
#    Present_Price  Transmission_Manual  Seller_Type_Individual^2  \
# 0       2.032689          1456.437013                  0.104702
#
#    Age Seller_Type_Individual Transmission_Manual  \
# 0                                      622.162724
#
#    Kms_Driven Fuel_Type_Diesel Transmission_Manual     Age^4  \
# 0                                              0.0  3.037674
#
#    Age^2 Present_Price^2  Age^2 Owner Transmission_Manual  \
# 0               7.201323                              0.0
#
#    Age^2 Fuel_Type_Diesel Seller_Type_Individual  \
# 0                                            0.0
#
#    Age^2 Fuel_Type_Diesel Transmission_Manual  \
# 0                                         0.0
#
#    Age Present_Price^2 Fuel_Type_Diesel  \
# 0                                   0.0
#
#    Age Kms_Driven^2 Seller_Type_Individual  Present_Price^4  \
# 0                              4173.849898        17.071962
#
#    Present_Price^2 Fuel_Type_Diesel Transmission_Manual  \
# 0                                                0.0
#
#    Present_Price^2 Seller_Type_Individual Transmission_Manual  \
# 0                                        1947.199385
#
#    Present_Price Kms_Driven^2 Owner  \
# 0                               0.0
#
#    Present_Price Kms_Driven Owner Transmission_Manual  \
# 0                                                0.0
#
#    Present_Price Owner Seller_Type_Individual Transmission_Manual  \
# 0                                                0.0
#
#    Kms_Driven^3 Fuel_Type_Diesel  Kms_Driven^3 Transmission_Manual
# 0                            0.0                      1.406626e+09

# %%
import pickle
file_path = "E:\\python\\2.PROJECTS\\car sales prediction\\artifacts\\standard_scaler.pkl"
with open(file_path, 'rb') as f:
    scaler = pickle.load(f)
scaler
# Out:
# StandardScaler()

# %%
df = scaler.transform(df_poly)
df[0]
# Out:
# array([ 0.12704453,  0.33421857,  1.33666245,  1.49605484, -0.42550549,
#        -0.09037395, -0.11797526, -0.19360681, -0.06933752, -0.41718782,
#        -0.43419083,  0.88620214, -0.37867927, -0.41504203,  6.7087212 ,
#        -0.12957343, -0.16639855, -0.11973345, -0.39084331, -0.1578474 ])

# %%
df
# Out:
# array([[ 0.12704453,  0.33421857,  1.33666245,  1.49605484, -0.42550549,
#         -0.09037395, -0.11797526, -0.19360681, -0.06933752, -0.41718782,
#         -0.43419083,  0.88620214, -0.37867927, -0.41504203,  6.7087212 ,
#         -0.12957343, -0.16639855, -0.11973345, -0.39084331, -0.1578474 ]])

# %%
new_df = pd.DataFrame(data = df, columns=df_poly.columns)

# %%
new_df
# Out:
#    Present_Price  Transmission_Manual  Seller_Type_Individual^2  \
# 0       0.127045             0.334219                  1.336662
#
#    Age Seller_Type_Individual Transmission_Manual  \
# 0                                        1.496055
#
#    Kms_Driven Fuel_Type_Diesel Transmission_Manual     Age^4  \
# 0                                        -0.425505 -0.090374
#
#    Age^2 Present_Price^2  Age^2 Owner Transmission_Manual  \
# 0              -0.117975                        -0.193607
#
#    Age^2 Fuel_Type_Diesel Seller_Type_Individual  \
# 0                                      -0.069338
#
#    Age^2 Fuel_Type_Diesel Transmission_Manual  \
# 0                                   -0.417188
#
#    Age Present_Price^2 Fuel_Type_Diesel  \
# 0                             -0.434191
#
#    Age Kms_Driven^2 Seller_Type_Individual  Present_Price^4  \
# 0                                 0.886202        -0.378679
#
#    Present_Price^2 Fuel_Type_Diesel Transmission_Manual  \
# 0                                          -0.415042
#
#    Present_Price^2 Seller_Type_Individual Transmission_Manual  \
# 0                                           6.708721
#
#    Present_Price Kms_Driven^2 Owner  \
# 0                         -0.129573
#
#    Present_Price Kms_Driven Owner Transmission_Manual  \
# 0                                          -0.166399
#
#    Present_Price Owner Seller_Type_Individual Transmission_Manual  \
# 0                                          -0.119733
#
#    Kms_Driven^3 Fuel_Type_Diesel  Kms_Driven^3 Transmission_Manual
# 0                      -0.390843                         -0.157847

# %%
import pickle
file_path = "E:\\python\\2.PROJECTS\\car sales prediction\\artifacts\\elastic_poly_reg.pkl"
with open(file_path, 'rb') as f:
    model = pickle.load(f)
model
# Out:
# ElasticNetCV(cv=4, l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 0.995, 1],
#              max_iter=100000)

# %%
# file_path = 'E:\\python\\2.PROJECTS\\car sales prediction\\artifacts\\rf_model.pkl'
# with open(file_path, 'rb') as f:
#     model = pickle.load(f)

# %%
result = model.predict(df)

# %%
result
# Out:
# array([1.43298058])

# %%
import numpy as np
from scipy.special import inv_boxcox

# %%
x = inv_boxcox(result,fitted_lambda['Selling_Price'])

# %%
x
# Out:
# array([4.35052854])
